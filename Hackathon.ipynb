# %% [markdown]
# <center><h2>Train Data</h2></center>

# %% [markdown]
# #### Import libraries for cleaning

# %%
import pandas as pd
import numpy as np

# %%
data_df=pd.read_excel("training_data.xlsx")

# %%
data_df
# Out:
#       ID              Severity Ventilation  Mean Age  % Male  Any Comorbidity  \
# 0      1                   All        Both       NaN  0.6230           0.4760
# 1      1  Severe/Critical Only        Both       NaN  0.7037           0.6667
# 2      1                   All        Both       NaN  0.5912           0.4015
# 3      2                   All        Both       NaN  0.6030              NaN
# 4      2                   All        Both       NaN  0.6160              NaN
# ..   ...                   ...         ...       ...     ...              ...
# 470  197  Severe/Critical Only         NaN       NaN  0.6630              NaN
# 471  198                   NaN        Both       NaN  0.6600              NaN
# 472  199  Severe/Critical Only        Both      65.0  0.5900           0.7100
# 473  199  Severe/Critical Only        Both      66.0  0.5600           0.7100
# 474  199  Severe/Critical Only        Both      64.0  0.6500           0.7100
#
# ...

# %%
data_df.describe()
# Out:
#                ID    Mean Age      % Male  Any Comorbidity  Hypertension  \
# count  475.000000  252.000000  430.000000        222.00000    309.000000
# mean    94.324211   51.093536    0.547413          0.48413      0.286662
# std     51.058213   18.572915    0.263608          0.35929      0.288207
# min      1.000000    0.170000    0.000000          0.00000      0.000000
# 25%     58.500000   43.300000    0.451175          0.18050      0.078000
# 50%     96.000000   52.450000    0.540600          0.40075      0.206000
# 75%    131.500000   64.000000    0.670000          0.82000      0.395000
# max    199.000000  100.000000    1.000000          1.00000      1.000000
#
#          Diabetes  Cardiovascular Disease (incl. CAD)  \
# count  325.000000                          295.000000
# mean     0.147790                            0.142180
# std      0.201715                            0.241088
# min      0.000000                            0.000000
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 91 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        475 non-null    int64
#  1   Severity                                  458 non-null    object
#  2   Ventilation                               301 non-null    object
#  3   Mean Age                                  252 non-null    float64
#  4   % Male                                    430 non-null    float64
#  5   Any Comorbidity                           222 non-null    float64
#  6   Hypertension                              309 non-null    float64
#  7   Diabetes                                  325 non-null    float64
#  8   Cardiovascular Disease (incl. CAD)        295 non-null    float64
#  9   Chronic obstructive lung (COPD)           262 non-null    float64
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains("unnamed",case=False)],axis=1,inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        475 non-null    int64
#  1   Severity                                  458 non-null    object
#  2   Ventilation                               301 non-null    object
#  3   Mean Age                                  252 non-null    float64
#  4   % Male                                    430 non-null    float64
#  5   Any Comorbidity                           222 non-null    float64
#  6   Hypertension                              309 non-null    float64
#  7   Diabetes                                  325 non-null    float64
#  8   Cardiovascular Disease (incl. CAD)        295 non-null    float64
#  9   Chronic obstructive lung (COPD)           262 non-null    float64
# ...

# %%
# checking checking correlation of data frame to drop other columns
data_df.corr()
# Out:
#                                                 ID  Mean Age    % Male  \
# ID                                        1.000000 -0.034119  0.061225
# Mean Age                                 -0.034119  1.000000 -0.034721
# % Male                                    0.061225 -0.034721  1.000000
# Any Comorbidity                           0.042305  0.676156 -0.024093
# Hypertension                              0.017327  0.517924  0.143473
# Diabetes                                  0.008696  0.339447 -0.176059
# Cardiovascular Disease (incl. CAD)        0.036176  0.516412  0.084111
# Chronic obstructive lung (COPD)           0.012213  0.349858  0.084755
# Cancer (Any)                              0.046954  0.127316 -0.152716
# Liver Disease (any)                      -0.037800 -0.214303  0.117434
# Cerebrovascular Disease                  -0.142358  0.151515  0.139738
# Chronic kidney/renal disease              0.072585  0.258589  0.089955
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(36,24))
sns.heatmap(data_df.corr(),annot=True,cmap="Blues");

# %%
#dropping %male column
#data_df.drop(["% Male"],inplace=True,axis=1)

# %%
#data_df.drop(["ID"],inplace=True,axis=1)

# %%
# Filling black spaces
for i in data_df.columns:
    if data_df[i].dtype=='float64':
        data_df[i].fillna(0.0,inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 53 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Severity                                  458 non-null    object
#  1   Ventilation                               301 non-null    object
#  2   Mean Age                                  475 non-null    float64
#  3   Any Comorbidity                           475 non-null    float64
#  4   Hypertension                              475 non-null    float64
#  5   Diabetes                                  475 non-null    float64
#  6   Cardiovascular Disease (incl. CAD)        475 non-null    float64
#  7   Chronic obstructive lung (COPD)           475 non-null    float64
#  8   Cancer (Any)                              475 non-null    float64
#  9   Liver Disease (any)                       475 non-null    float64
# ...

# %%
data_df['Mean Age'].replace(to_replace=0.0,value=data_df['Mean Age'].mean(),inplace=True)

# %%
data_df
# Out:
#                  Severity Ventilation   Mean Age  Any Comorbidity  \
# 0                     All        Both  27.106465           0.4760
# 1    Severe/Critical Only        Both  27.106465           0.6667
# 2                     All        Both  27.106465           0.4015
# 3                     All        Both  27.106465           0.0000
# 4                     All        Both  27.106465           0.0000
# ..                    ...         ...        ...              ...
# 470  Severe/Critical Only         NaN  27.106465           0.0000
# 471                   NaN        Both  27.106465           0.0000
# 472  Severe/Critical Only        Both  65.000000           0.7100
# 473  Severe/Critical Only        Both  66.000000           0.7100
# 474  Severe/Critical Only        Both  64.000000           0.7100
#
#      Hypertension  Diabetes  Cardiovascular Disease (incl. CAD)  \
# 0          0.3000    0.1900                              0.0800
# ...

# %%
data_df.Mortality.unique()
# Out:
# array([0.28, 1, 0, 0.16, 0.15, 0.17, 0.04, 0.07, 0.06, 0.25, 0.64, 0.55,
#        0.79, 0.01, 0.08, 0.22, 0.38, 0.11, 0.1, 0.03, 0.35, 0.67, 0.52,
#        0.34, 0.45, 0.2, 0.05, 0.36, 0.23, 0.3, 0.09, 0.49, 0.02, 0.14,
#        0.12, 0.21, 0.62, 0.48, 0.47, 0.54, 0.4, 0.63, 0.6, 0.51, 0.5,
#        0.27, 0.56, 0.18, 0.29, 0.76, 0.19, 'na', 0.26, '0%%', 0.41, 0.7,
#        0.66, 0.42, 0.9, 0.32, 0.39, 0.58], dtype=object)

# %%
data_df.Mortality.replace('0%%',0.0,inplace=True)

# %%
data_df.Mortality.unique()
# Out:
# array([0.28, 1, 0, 0.16, 0.15, 0.17, 0.04, 0.07, 0.06, 0.25, 0.64, 0.55,
#        0.79, 0.01, 0.08, 0.22, 0.38, 0.11, 0.1, 0.03, 0.35, 0.67, 0.52,
#        0.34, 0.45, 0.2, 0.05, 0.36, 0.23, 0.3, 0.09, 0.49, 0.02, 0.14,
#        0.12, 0.21, 0.62, 0.48, 0.47, 0.54, 0.4, 0.63, 0.6, 0.51, 0.5,
#        0.27, 0.56, 0.18, 0.29, 0.76, 0.19, 'na', 0.26, 0.41, 0.7, 0.66,
#        0.42, 0.9, 0.32, 0.39, 0.58], dtype=object)

# %%
data_df.Mortality.replace('na',0,inplace=True)

# %%
data_df.Mortality.unique()
# Out:
# array([0.28, 1.  , 0.  , 0.16, 0.15, 0.17, 0.04, 0.07, 0.06, 0.25, 0.64,
#        0.55, 0.79, 0.01, 0.08, 0.22, 0.38, 0.11, 0.1 , 0.03, 0.35, 0.67,
#        0.52, 0.34, 0.45, 0.2 , 0.05, 0.36, 0.23, 0.3 , 0.09, 0.49, 0.02,
#        0.14, 0.12, 0.21, 0.62, 0.48, 0.47, 0.54, 0.4 , 0.63, 0.6 , 0.51,
#        0.5 , 0.27, 0.56, 0.18, 0.29, 0.76, 0.19, 0.26, 0.41, 0.7 , 0.66,
#        0.42, 0.9 , 0.32, 0.39, 0.58])

# %%
data_df.replace('na',0,inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 54 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Severity                                  458 non-null    object
#  1   Ventilation                               301 non-null    object
#  2   Mean Age                                  475 non-null    float64
#  3   Any Comorbidity                           475 non-null    float64
#  4   Hypertension                              475 non-null    float64
#  5   Diabetes                                  475 non-null    float64
#  6   Cardiovascular Disease (incl. CAD)        475 non-null    float64
#  7   Chronic obstructive lung (COPD)           475 non-null    float64
#  8   Cancer (Any)                              475 non-null    float64
#  9   Liver Disease (any)                       475 non-null    float64
# ...

# %%
data_df.drop(["Severity","Ventilation"],axis=1,inplace=True)

# %%
f=[]
for i in data_df.columns:
    if data_df[i].dtype=='float64' and i != 'Mortality':
        f.append(i)
data_df["all"]=data_df[f].sum(axis=1)
data_df["all"]
# Out:
# 0      3444.418096
# 1      3100.563496
# 2      3540.363496
# 3      2495.105896
# 4      2463.070396
#           ...
# 470     163.387396
# 471     249.379396
# 472     374.091300
# 473     377.040000
# 474     367.890000
# Name: all, Length: 475, dtype: float64

# %% [markdown]
# <center><h2>Test Data</h2></center>

# %%
test_df=pd.read_excel("test_data.xlsx")

# %%
test_df
# Out:
#      ID              Severity           Ventilation   Mean Age  % Male  \
# 0   155             Mild only                  Both  48.900000  0.3410
# 1   156  Severe/Critical Only                  Both        NaN  0.7500
# 2   156  Severe/Critical Only      Ventilation only        NaN  0.7900
# 3   156  Severe/Critical Only  Non-ventilation only        NaN  0.6800
# 4   157                   All                  Both  52.943333  0.4654
# 5   157                   All                  Both  44.740000  0.2927
# 6   157                   All                  Both  52.680000  0.4938
# 7   157                   All                  Both  61.410000  0.6098
# 8   158                   All                  Both  36.020000  0.5198
# 9   158                   All                  Both  40.500000  0.5880
# 10  158                   All                  Both  26.500000  0.3750
# 11  159                   All                   NaN  49.000000  0.4700
# ...

# %%
# Filling black spaces
for i in test_df.columns:
    if test_df[i].dtype=='float64':
        test_df[i].fillna(0.0,inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 54 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        53 non-null     int64
#  1   Severity                                  53 non-null     object
#  2   Ventilation                               46 non-null     object
#  3   Mean Age                                  53 non-null     float64
#  4   % Male                                    53 non-null     float64
#  5   Any Comorbidity                           53 non-null     float64
#  6   Hypertension                              53 non-null     float64
#  7   Diabetes                                  53 non-null     float64
#  8   Cardiovascular Disease (incl. CAD)        53 non-null     float64
#  9   Chronic obstructive lung (COPD)           53 non-null     float64
# ...

# %%
test_df.columns
# Out:
# Index(['ID', 'Severity', 'Ventilation', 'Mean Age', '% Male',
#        'Any Comorbidity', 'Hypertension', 'Diabetes',
#        'Cardiovascular Disease (incl. CAD)', 'Chronic obstructive lung (COPD)',
#        'Cancer (Any)', 'Liver Disease (any)', 'Cerebrovascular Disease',
#        'Chronic kidney/renal disease', 'Other', 'Fever (temperature ≥37·3°C)',
#        'Average temperature (celsius)', 'Max temperature (celsius)',
#        'Respiratory rate > 24 breaths per min', 'Cough',
#        'Shortness of Breath (dyspnoea)', 'Headache', 'Sputum (/Expectoration)',
#        'Myalgia (Muscle Pain)', 'Fatigue', 'Diarrhoea', 'Nausea or Vomiting',
#        'Loss of Appetite/Anorexia', 'Disease Severity Asymptomatic',
#        'Disease Severity General', 'Disease Severity Severe',
#        'Disease Severity Critical', 'White Blood Cell Count (10^9/L) - Median',
#        'White Blood Cell Count (10^9/L) - LQ',
#        'White Blood Cell Count (10^9/L) - UQ',
# ...

# %%
# dropping all the columns which are not in train data
for c in test_df.columns:
    if c not in data_df.columns:
        test_df.drop(c,axis=1,inplace=True)

# %%
test_final.columns
# Out:
# Index(['ID', 'Severity', 'Ventilation', 'Mean Age', 'Any Comorbidity',
#        'Hypertension', 'Diabetes', 'Cardiovascular Disease (incl. CAD)',
#        'Chronic obstructive lung (COPD)', 'Cancer (Any)',
#        'Liver Disease (any)', 'Cerebrovascular Disease',
#        'Chronic kidney/renal disease', 'Other', 'Fever (temperature ≥37·3°C)',
#        'Average temperature (celsius)', 'Max temperature (celsius)',
#        'Respiratory rate > 24 breaths per min', 'Cough',
#        'Shortness of Breath (dyspnoea)', 'Headache', 'Sputum (/Expectoration)',
#        'Myalgia (Muscle Pain)', 'Fatigue', 'Diarrhoea', 'Nausea or Vomiting',
#        'Loss of Appetite/Anorexia', 'Disease Severity Asymptomatic',
#        'Disease Severity General', 'Disease Severity Severe',
#        'Disease Severity Critical', 'White Blood Cell Count (10^9/L) - Median',
#        'White Blood Cell Count (10^9/L) - LQ',
#        'White Blood Cell Count (10^9/L) - UQ',
# ...

# %%
test_df['Mean Age'].replace(to_replace=0.0,value=data_df['Mean Age'].mean(),inplace=True)

# %%
test_df.drop(["Severity","Ventilation"],axis=1,inplace=True)

# %%
f=[]
for i in test_df.columns:
    if test_df[i].dtype=='float64' and i != 'Mortality':
        f.append(i)
test_df["all"]=test_df[f].sum(axis=1)
test_df["all"]
# Out:
# 0      648.270000
# 1      242.772238
# 2      277.132238
# 3      194.152238
# 4      744.027467
# 5      718.296200
# 6      732.480800
# 7      781.217000
# 8      125.000000
# 9      160.400000
# 10     117.600000
# 11     106.196000
# 12      97.640000
# 13     144.800000
# 14    1871.452000
# 15    1798.720000
# 16    1855.840000
# 17     297.600000
# 18     238.000000
# 19     142.200000
# 20     291.000000
# 21      39.832238
# 22    1884.480000
# 23    1868.640000
# 24    1978.800000
# 25      97.754000
# 26     100.062000
# 27      85.064000
# 28    2199.368000
# 29    2202.778000
# 30    2133.050000
# 31      86.316000
# 32      91.732000
# 33      84.404000
# 34      85.814000
# 35     103.000000
# 36     180.026000
# 37     175.624000
# 38      48.552438
# 39      96.000000
# 40     148.954000
# 41      39.832238
# 42      39.832238
# 43      39.832238
# 44     320.408038
# 45     323.392238
# 46     317.930238
# 47      41.832238
# 48     116.744838
# 49     117.388238
# ...

# %%
X_train = data_df['all'].values.reshape(-1,1)
X_test = test_df['all'].values.reshape(-1,1)
y_train = data_df['Mortality'].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %%
reg = LinearRegression().fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[0.19705888],
#        [0.20407063],
#        [0.20347648],
#        [0.20491135],
#        [0.19540306],
#        [0.195848  ],
#        [0.19560273],
#        [0.19475999],
#        [0.20610711],
#        [0.20549499],
#        [0.20623507],
#        [0.20643227],
#        [0.20658021],
#        [0.20576474],
#        [0.17590796],
#        [0.17716562],
#        [0.17617792],
#        [0.20312256],
#        [0.20415315],
#        [0.20580969],
#        [0.20323669],
#        [0.20757981],
#        [0.17568268],
#        [0.17595658],
#        [0.17405173],
#        [0.20657824],
#        [0.20653833],
#        [0.20679767],
#        [0.17023773],
#        [0.17017876],
#        [0.17138448],
#        [0.20677602],
#        [0.20668237],
#        [0.20680909],
#        [0.20678471],
#        [0.20648753],
#        [0.20515562],
#        [0.20523174],
#        [0.20742902],
#        [0.20660857],
#        [0.20569291],
#        [0.20757981],
#        [0.20757981],
# ...

# %%
from sklearn.metrics import mean_squared_error
y_pred_train = reg.predict(X_train)
mean_squared_error(y_train,y_pred_train)
# Out:
# 0.10361226475062614

# %%
t_df=pd.read_excel('test_data.xlsx')

# %%
new_df = pd.DataFrame(t_df['ID'])

# %%
new_df['Mortality']=y_pred

# %%
new_df.head()
# Out:
#     ID  Mortality
# 0  155   0.197059
# 1  156   0.204071
# 2  156   0.203476
# 3  156   0.204911
# 4  157   0.195403

# %%
new_df.to_csv('Harsimar_sol.csv',index=None)
